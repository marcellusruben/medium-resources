# %%
import pandas as pd
import numpy as np

# %%
prem_league = pd.read_csv('D:/PL Dataset/premierLeague_tables_1992-2017.csv')

# %%
prem_league.head()
# Out:
#     season               team  points   w   d   l   gf  ga  gd  pld  ...  d_h  \
# 0  2017-18    Manchester City     100  32   4   2  106  27  79   38  ...    2
# 1  2017-18  Manchester United      81  25   6   7   68  28  40   38  ...    2
# 2  2017-18  Tottenham Hotspur      77  23   8   7   74  36  38   38  ...    4
# 3  2017-18          Liverpool      75  21  12   5   84  38  46   38  ...    7
# 4  2017-18            Chelsea      70  21   7  10   62  38  24   38  ...    4
#
#    d_a  l_h  l_a  gf_h  gf_a  ga_h  ga_a  gd_h  gd_a
# 0    2    1    1    61    45    14    13    47    32
# 1    4    2    5    38    30     9    19    29    11
# 2    4    2    5    40    34    16    20    24    14
# 3    5    0    5    45    39    10    28    35    11
# 4    3    4    6    30    32    16    22    14    10
#
# [5 rows x 26 columns]

# %%
prem_league = prem_league[['season', 'team', 'points']]

# %%
prem_league.head()
# Out:
#     season               team  points
# 0  2017-18    Manchester City     100
# 1  2017-18  Manchester United      81
# 2  2017-18  Tottenham Hotspur      77
# 3  2017-18          Liverpool      75
# 4  2017-18            Chelsea      70

# %%
prem_league.dtypes
# Out:
# season    object
# team      object
# points     int64
# dtype: object

# %%
df = prem_league.pivot_table(values = 'points',index = ['season'], columns = 'team')

# %%
df.head()
# Out:
# team     Arsenal  Aston Villa  Barnsley  Birmingham City  Blackburn Rovers  \
# season
# 1992-93     56.0         74.0       NaN              NaN              71.0
# 1993-94     71.0         57.0       NaN              NaN              84.0
# 1994-95     51.0         48.0       NaN              NaN              89.0
# 1995-96     63.0         63.0       NaN              NaN              61.0
# 1996-97     68.0         61.0       NaN              NaN              42.0
#
# team     Blackpool  Bolton Wanderers  Bournemouth  Bradford City  \
# season
# 1992-93        NaN               NaN          NaN            NaN
# 1993-94        NaN               NaN          NaN            NaN
# 1994-95        NaN               NaN          NaN            NaN
# 1995-96        NaN              29.0          NaN            NaN
# 1996-97        NaN               NaN          NaN            NaN
#
# team     Brighton and Hove Albion  ...  Sunderland  Swansea City  \
# season                             ...
# 1992-93                       NaN  ...         NaN           NaN
# 1993-94                       NaN  ...         NaN           NaN
# 1994-95                       NaN  ...         NaN           NaN
# 1995-96                       NaN  ...         NaN           NaN
# 1996-97                       NaN  ...        40.0           NaN
#
# team     Swindon Town  Tottenham Hotspur  Watford  West Bromwich Albion  \
# season
# 1992-93           NaN               59.0      NaN                   NaN
# 1993-94          30.0               45.0      NaN                   NaN
# 1994-95           NaN               62.0      NaN                   NaN
# 1995-96           NaN               61.0      NaN                   NaN
# 1996-97           NaN               46.0      NaN                   NaN
#
# team     West Ham United  Wigan Athletic  Wimbledon FC  \
# season
# 1992-93              NaN             NaN          54.0
# 1993-94             52.0             NaN          65.0
# 1994-95             50.0             NaN          56.0
# 1995-96             51.0             NaN          41.0
# 1996-97             42.0             NaN          56.0
#
# team     Wolverhampton Wanderers
# season
# 1992-93                      NaN
# 1993-94                      NaN
# 1994-95                      NaN
# 1995-96                      NaN
# 1996-97                      NaN
#
# [5 rows x 49 columns]

# %%
df.fillna(0, inplace=True)
df.sort_values(list(df.columns),inplace=True)
df = df.sort_index()

# %%
df.head()
# Out:
# team     Arsenal  Aston Villa  Barnsley  Birmingham City  Blackburn Rovers  \
# season
# 1992-93     56.0         74.0       0.0              0.0              71.0
# 1993-94     71.0         57.0       0.0              0.0              84.0
# 1994-95     51.0         48.0       0.0              0.0              89.0
# 1995-96     63.0         63.0       0.0              0.0              61.0
# 1996-97     68.0         61.0       0.0              0.0              42.0
#
# team     Blackpool  Bolton Wanderers  Bournemouth  Bradford City  \
# season
# 1992-93        0.0               0.0          0.0            0.0
# 1993-94        0.0               0.0          0.0            0.0
# 1994-95        0.0               0.0          0.0            0.0
# 1995-96        0.0              29.0          0.0            0.0
# 1996-97        0.0               0.0          0.0            0.0
#
# team     Brighton and Hove Albion  ...  Sunderland  Swansea City  \
# season                             ...
# 1992-93                       0.0  ...         0.0           0.0
# 1993-94                       0.0  ...         0.0           0.0
# 1994-95                       0.0  ...         0.0           0.0
# 1995-96                       0.0  ...         0.0           0.0
# 1996-97                       0.0  ...        40.0           0.0
#
# team     Swindon Town  Tottenham Hotspur  Watford  West Bromwich Albion  \
# season
# 1992-93           0.0               59.0      0.0                   0.0
# 1993-94          30.0               45.0      0.0                   0.0
# 1994-95           0.0               62.0      0.0                   0.0
# 1995-96           0.0               61.0      0.0                   0.0
# 1996-97           0.0               46.0      0.0                   0.0
#
# team     West Ham United  Wigan Athletic  Wimbledon FC  \
# season
# 1992-93              0.0             0.0          54.0
# 1993-94             52.0             0.0          65.0
# 1994-95             50.0             0.0          56.0
# 1995-96             51.0             0.0          41.0
# 1996-97             42.0             0.0          56.0
#
# team     Wolverhampton Wanderers
# season
# 1992-93                      0.0
# 1993-94                      0.0
# 1994-95                      0.0
# 1995-96                      0.0
# 1996-97                      0.0
#
# [5 rows x 49 columns]

# %%
df.iloc[:, 0:-1] = df.iloc[:, 0:-1].cumsum()

# %%
df[0:10]
# Out:
# team     Arsenal  Aston Villa  Barnsley  Birmingham City  Blackburn Rovers  \
# season
# 1992-93     56.0         74.0       0.0              0.0              71.0
# 1993-94    127.0        131.0       0.0              0.0             155.0
# 1994-95    178.0        179.0       0.0              0.0             244.0
# 1995-96    241.0        242.0       0.0              0.0             305.0
# 1996-97    309.0        303.0       0.0              0.0             347.0
# 1997-98    387.0        360.0      35.0              0.0             405.0
# 1998-99    465.0        415.0      35.0              0.0             440.0
# 1999-00    538.0        473.0      35.0              0.0             440.0
# 2000-01    608.0        527.0      35.0              0.0             440.0
# 2001-02    695.0        577.0      35.0              0.0             486.0
#
# team     Blackpool  Bolton Wanderers  Bournemouth  Bradford City  \
# season
# 1992-93        0.0               0.0          0.0            0.0
# 1993-94        0.0               0.0          0.0            0.0
# 1994-95        0.0               0.0          0.0            0.0
# 1995-96        0.0              29.0          0.0            0.0
# 1996-97        0.0              29.0          0.0            0.0
# 1997-98        0.0              69.0          0.0            0.0
# 1998-99        0.0              69.0          0.0            0.0
# 1999-00        0.0              69.0          0.0           36.0
# 2000-01        0.0              69.0          0.0           62.0
# 2001-02        0.0             109.0          0.0           62.0
#
# team     Brighton and Hove Albion  ...  Sunderland  Swansea City  \
# season                             ...
# 1992-93                       0.0  ...         0.0           0.0
# 1993-94                       0.0  ...         0.0           0.0
# 1994-95                       0.0  ...         0.0           0.0
# 1995-96                       0.0  ...         0.0           0.0
# 1996-97                       0.0  ...        40.0           0.0
# 1997-98                       0.0  ...        40.0           0.0
# 1998-99                       0.0  ...        40.0           0.0
# 1999-00                       0.0  ...        98.0           0.0
# 2000-01                       0.0  ...       155.0           0.0
# 2001-02                       0.0  ...       195.0           0.0
#
# team     Swindon Town  Tottenham Hotspur  Watford  West Bromwich Albion  \
# season
# 1992-93           0.0               59.0      0.0                   0.0
# 1993-94          30.0              104.0      0.0                   0.0
# 1994-95          30.0              166.0      0.0                   0.0
# 1995-96          30.0              227.0      0.0                   0.0
# 1996-97          30.0              273.0      0.0                   0.0
# 1997-98          30.0              317.0      0.0                   0.0
# 1998-99          30.0              364.0      0.0                   0.0
# 1999-00          30.0              417.0     24.0                   0.0
# 2000-01          30.0              466.0     24.0                   0.0
# 2001-02          30.0              516.0     24.0                   0.0
#
# team     West Ham United  Wigan Athletic  Wimbledon FC  \
# season
# 1992-93              0.0             0.0          54.0
# 1993-94             52.0             0.0         119.0
# 1994-95            102.0             0.0         175.0
# 1995-96            153.0             0.0         216.0
# 1996-97            195.0             0.0         272.0
# 1997-98            251.0             0.0         316.0
# 1998-99            308.0             0.0         358.0
# 1999-00            363.0             0.0         391.0
# 2000-01            405.0             0.0         391.0
# 2001-02            458.0             0.0         391.0
#
# team     Wolverhampton Wanderers
# season
# 1992-93                      0.0
# 1993-94                      0.0
# 1994-95                      0.0
# 1995-96                      0.0
# 1996-97                      0.0
# 1997-98                      0.0
# 1998-99                      0.0
# 1999-00                      0.0
# 2000-01                      0.0
# 2001-02                      0.0
#
# [10 rows x 49 columns]

# %%
top_prem_clubs = set()

for index, row in df.iterrows():
    top_prem_clubs |= set(row[row > 0].sort_values(ascending=False).head(6).index)

df = df[top_prem_clubs]

# %%
df.head()
# Out:
# team     Everton  Queens Park Rangers  Newcastle United  Sheffield Wednesday  \
# season
# 1992-93     53.0                 63.0               0.0                 59.0
# 1993-94     97.0                123.0              77.0                123.0
# 1994-95    147.0                183.0             149.0                174.0
# 1995-96    208.0                216.0             227.0                214.0
# 1996-97    250.0                216.0             295.0                271.0
#
# team     Blackburn Rovers  Chelsea  Aston Villa  Norwich City  \
# season
# 1992-93              71.0     56.0         74.0          72.0
# 1993-94             155.0    107.0        131.0         125.0
# 1994-95             244.0    161.0        179.0         168.0
# 1995-96             305.0    211.0        242.0         168.0
# 1996-97             347.0    270.0        303.0         168.0
#
# team     Manchester United  Arsenal  Leeds United  Tottenham Hotspur  \
# season
# 1992-93               84.0     56.0          51.0               59.0
# 1993-94              176.0    127.0         121.0              104.0
# 1994-95              264.0    178.0         194.0              166.0
# 1995-96              346.0    241.0         237.0              227.0
# 1996-97              421.0    309.0         283.0              273.0
#
# team     Liverpool
# season
# 1992-93       59.0
# 1993-94      119.0
# 1994-95      193.0
# 1995-96      264.0
# 1996-97      332.0

# %%
import bar_chart_race as bcr

# %%
bcr.bar_chart_race(df = df, 
                   n_bars = 6, 
                   sort='desc',
                   title='Premier League Clubs Points Since 1992',
                   period_length  = 750,
                   filename = 'pl_clubs.mp4')

# %%
bcr.bar_chart_race(df, img_label_folder = 'PL clubs', n_bars=6, period_length = 750)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-ce2945036f6f> in <module>
# ----> 1 bcr.bar_chart_race(df, img_label_folder = 'PL clubs', n_bars=6, period_length = 750)
#
# TypeError: bar_chart_race() got an unexpected keyword argument 'img_label_folder'
